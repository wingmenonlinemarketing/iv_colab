# %% [markdown]
# <a href="https://colab.research.google.com/github/wingmenonlinemarketing/iv_colab/blob/master/Interne_Verlinkung_optimieren.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interne Verlinkung optimieren
#
# Notebook zum Webinar "pragmatische Optimierung der internen Verlinkung" von johan.huelsen@wngmn.de für audisto.com
#
# Im Webinar sind wir verschiedene Ansätze zur Optimierung der internen Verlinkung durchgegangen. Als Beispiel haben wir einen Crawl von web.dev genutzt.

# %% [markdown]
# # Initialisieren
#
# ## Notwendige Libraries laden

# %%
# Non-Standard Libraries installieren
# !pip install tldextract
# !pip install swifter 

import pandas as pd # Für Datenverarbeitung
import networkx as nx # Für PageRank
from google.colab import files # Für Dateiupload
import io # Für Dateiupload
import swifter # Zum Beschleunigen mancher Pandas-Funktionen
import tldextract # Zur Extraction von Domains aus URLs
import numpy as np # Für Logarithmus-Kram bei Backlinks
# Out:
# Collecting tldextract
#   Downloading https://files.pythonhosted.org/packages/12/cf/d0ff82625e53bd245d6173ce6333d190abbfcd94e4c30e54b4e16b474216/tldextract-2.2.3-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 1.6MB/s
# Collecting requests-file>=1.4
#   Downloading https://files.pythonhosted.org/packages/77/86/cdb5e8eaed90796aa83a6d9f75cfbd37af553c47a291cd47bc410ef9bdb2/requests_file-1.5.1-py2.py3-none-any.whl
# Requirement already satisfied: idna in /usr/local/lib/python3.6/dist-packages (from tldextract) (2.10)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from tldextract) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from requests-file>=1.4->tldextract) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->tldextract) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->tldextract) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->tldextract) (3.0.4)
# Installing collected packages: requests-file, tldextract
# Successfully installed requests-file-1.5.1 tldextract-2.2.3
# Collecting swifter
#   Downloading https://files.pythonhosted.org/packages/7c/07/ad5bda46a33f1d869eaf71f431615111f251adfbceb4e3a02d66ad402582/swifter-1.0.3-py3-none-any.whl
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (4.41.1)
# Requirement already satisfied: dask[complete]>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (1.0.5)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (0.7.1)
# Collecting modin[ray]>=0.7.4
#   Downloading https://files.pythonhosted.org/packages/e9/7c/7ff264198ce393153f75ad6fce9fef9eb7624602776ea9854e4f067712d8/modin-0.8.0-py3-none-manylinux1_x86_64.whl (387kB)
#      |████████████████████████████████| 389kB 3.8MB/s
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from swifter) (7.5.1)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from swifter) (3.1.5)
# Collecting psutil>=5.6.6
#   Downloading https://files.pythonhosted.org/packages/aa/3e/d18f2c04cf2b528e18515999b0c8e698c136db78f62df34eee89cee205f1/psutil-5.7.2.tar.gz (460kB)
#      |████████████████████████████████| 460kB 12.7MB/s
# Collecting distributed>=2.0; extra == "complete"
#   Downloading https://files.pythonhosted.org/packages/c8/aa/2675e14c4d9d4555f1ff627acf45a7ea0900fc1d4d0a53b8ef09898df334/distributed-2.24.0-py3-none-any.whl (651kB)
#      |████████████████████████████████| 655kB 14.4MB/s
# Requirement already satisfied: numpy>=1.13.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.19.0->swifter) (1.18.5)
# Requirement already satisfied: toolz>=0.7.3; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.19.0->swifter) (0.10.0)
# Requirement already satisfied: PyYaml; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.19.0->swifter) (3.13)
# Requirement already satisfied: bokeh>=1.0.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.19.0->swifter) (2.1.1)
# Requirement already satisfied: fsspec>=0.6.0; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.19.0->swifter) (0.8.0)
# Requirement already satisfied: cloudpickle>=0.2.1; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.19.0->swifter) (1.3.0)
# Collecting partd>=0.3.10; extra == "complete"
#   Downloading https://files.pythonhosted.org/packages/44/e1/68dbe731c9c067655bff1eca5b7d40c20ca4b23fd5ec9f3d17e201a6f36b/partd-1.1.0-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->swifter) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->swifter) (2018.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from modin[ray]>=0.7.4->swifter) (20.4)
# Requirement already satisfied: pyarrow<0.17; extra == "ray" in /usr/local/lib/python3.6/dist-packages (from modin[ray]>=0.7.4->swifter) (0.14.1)
# Collecting ray==0.8.6; extra == "ray"
#   Downloading https://files.pythonhosted.org/packages/ea/0b/f253e92aee1225d9d0ef21dd15514352ce87f6dbc55de70707bc9d52477f/ray-0.8.6-cp36-cp36m-manylinux1_x86_64.whl (21.9MB)
#      |████████████████████████████████| 21.9MB 1.5MB/s
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->swifter) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->swifter) (5.0.7)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (2.2.2)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.7.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (7.1.2)
# Requirement already satisfied: tornado>=5; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (5.1.1)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.0.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (49.6.0)
# Collecting contextvars; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Requirement already satisfied: Jinja2>=2.7 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (2.11.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (3.7.4.3)
# Requirement already satisfied: pillow>=4.0 in /usr/local/lib/python3.6/dist-packages (from bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (7.0.0)
# Collecting locket
#   Downloading https://files.pythonhosted.org/packages/d0/22/3c0f97614e0be8386542facb3a7dcfc2584f7b83608c02333bced641281c/locket-0.2.0.tar.gz
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->modin[ray]>=0.7.4->swifter) (2.4.7)
# Collecting py-spy>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/8e/a7/ab45c9ee3c4654edda3efbd6b8e2fa4962226718a7e3e3be6e3926bf3617/py_spy-0.3.3-py2.py3-none-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 43.7MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (3.0.12)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.6/dist-packages (from ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (1.31.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (2.6.0)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/7c/39/7eb5f98d24904e0f6d3edb505d4aa60e3ef83c0a58d6fe18244a51757247/aiohttp-3.6.2-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 44.9MB/s
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (from ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (2.0.3)
# Collecting redis<3.5.0,>=3.3.2
#   Downloading https://files.pythonhosted.org/packages/f0/05/1fc7feedc19c123e7a95cfc9e7892eb6cdd2e5df4e9e8af6384349c1cc3d/redis-3.4.1-py2.py3-none-any.whl (71kB)
#      |████████████████████████████████| 71kB 7.5MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (3.12.4)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (2.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.6.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from zict>=0.1.3->distributed>=2.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.0.1)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 356kB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.7->bokeh>=1.0.0; extra == "complete"->dask[complete]>=0.19.0->swifter) (1.1.1)
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/a0/b4/2cbeaf2c3ea53865d9613b315fe24e78c66acedb1df7e4be4e064c87203b/yarl-1.5.1-cp36-cp36m-manylinux1_x86_64.whl (257kB)
#      |████████████████████████████████| 266kB 45.2MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (20.1.0)
# Collecting multidict<5.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/1a/95/f50352b5366e7d579e8b99631680a9e32e1b22adfa1629a8f23b1d22d5e2/multidict-4.7.6-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 44.4MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (3.0.4)
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (4.6.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (19.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.6/dist-packages (from yarl<2.0,>=1.0->aiohttp->ray==0.8.6; extra == "ray"->modin[ray]>=0.7.4->swifter) (2.10)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.4.4)
# Building wheels for collected packages: psutil, contextvars, locket, idna-ssl
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.2-cp36-cp36m-linux_x86_64.whl size=279870 sha256=840a19e6374e936460966faabc72c588ff317e9af1a76e5077dfb215dfc2012d
#   Stored in directory: /root/.cache/pip/wheels/39/a0/f5/c4fa280463e29aea07797acb5312358fefb067c1f4f98e11b1
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7666 sha256=1861fda1eedb4878be7785d9040b09111171387fe8e2fa2137e2f7fa98bbb4bd
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
#   Building wheel for locket (setup.py) ... done
#   Created wheel for locket: filename=locket-0.2.0-cp36-none-any.whl size=4040 sha256=aea69d5c0bb266243d72733149887dcb710f0e280ca07b7cb3ceac2d93e3ed1b
#   Stored in directory: /root/.cache/pip/wheels/26/1e/e8/4fa236ec931b1a0cdd61578e20d4934d7bf188858723b84698
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3161 sha256=dd85b5dc381cdfc0668b631ae9a1bee63a589fa1cd951c1468c1a6dcc8212dd2
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built psutil contextvars locket idna-ssl
# ERROR: distributed 2.24.0 has requirement cloudpickle>=1.5.0, but you'll have cloudpickle 1.3.0 which is incompatible.
# Installing collected packages: py-spy, colorama, multidict, yarl, idna-ssl, async-timeout, aiohttp, redis, ray, modin, psutil, swifter, immutables, contextvars, distributed, locket, partd
#   Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# Successfully installed aiohttp-3.6.2 async-timeout-3.0.1 colorama-0.4.3 contextvars-2.4 distributed-2.24.0 idna-ssl-1.1.0 immutables-0.14 locket-0.2.0 modin-0.8.0 multidict-4.7.6 partd-1.1.0 psutil-5.7.2 py-spy-0.3.3 ray-0.8.6 redis-3.4.1 swifter-1.0.3 yarl-1.5.1

# %% [markdown]
# ## ScreamingFrog Exporte hochladen

# %%
# Upload files (bei größeren Datenmengen als .gz hochladen)
print('Upload: all_outlinks.csv, redirects.csv, internal_all.csv')
uploaded = files.upload()
# Out:
# Upload: all_outlinks.csv, redirects.csv, internal_all.csv
#      <input type="file" id="files-df0ed1af-62db-442c-bab0-648c28b77bc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df0ed1af-62db-442c-bab0-648c28b77bc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving redirects.csv to redirects.csv
# Saving all_outlinks.csv to all_outlinks.csv
# Saving backlinks.csv to backlinks.csv
# Saving internal_all.csv to internal_all.csv

# %% [markdown]
# ## Variablen definieren

# %%
# Für welche Domain sollen Links als interne Links gewertet werden?
domain = 'web.dev'

# Wie sollen Link-Positionen gewichtet werden (beim Droppen von Duplikaten werden wichtige Links (und deren Linktexte) beibehalten und weniger wichtige gelöscht)

element_weights = {
    'Header': 0.05,
    'Navigation': 0.1,
    'Footer': 0.05,
    'Content': 1,
    'Aside': 0.5
}

# %% [markdown]
# ## Funktionen initialisieren

# %%
# main functions
check_internal = lambda x: '.'.join(tldextract.extract(x)[1:3]) == domain

# because we will reload the files a lot
def read_files():
  docs = read_file('internal_all.csv')
  docs = docs[docs['Address'].str.endswith('/index.json')==False] # Komische URLs im Crawl

  canonicals = docs[['Address','Canonical Link Element 1', 'Redirect URL']]
  canonicals['Final Address'] = canonicals['Canonical Link Element 1'].fillna(canonicals['Redirect URL'])
  canonicals = canonicals[canonicals['Final Address'] == canonicals['Final Address']] #Final Address given
  canonicals = canonicals[canonicals['Address'] != canonicals['Final Address']] # Final Address not Address
  canonicals = canonicals.drop(columns=['Canonical Link Element 1', 'Redirect URL'])
  
  redirects = read_file('redirects.csv')[['Address', 'Final Address']]

  links = read_file('all_outlinks.csv')
  links = normalize_links(
      links,
      redirects=redirects,
      canonicals=canonicals)

  return links, docs


def read_file(filename):
  '''read uploaded file to variable'''
  return pd.read_csv(io.BytesIO(uploaded[filename]))

def simulate_pagerank(links, personalization=None, weight=None):
  """To include Backlink values for weighting of nodes use a dictionary with a
personalization score for all URLs between 0 and 1 you could build something
like Kevins TIPR https://www.kevin-indig.com/internal-link-optimization-with-tipr/
for example: Fetch Backlinks, score them with Backlinks visibility or referrers
and use a log for normalization
  
To increase the impact of specific links (f.e. in content) one could use
sth. like: https://stackoverflow.com/questions/9136539/how-do-weighted-edges-affect-pagerank-in-networkx
Library: https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.algorithms.link_analysis.pagerank_alg.pagerank.html
"""
  if weight:
    g = nx.from_pandas_edgelist(links, 'Source', 'Destination', 'weights')
  else:
    g = nx.from_pandas_edgelist(links, 'Source', 'Destination')

  # Calculate Pagerank
  pr = nx.pagerank_scipy(
      g,
      alpha=0.85,
      weight=weight, # Link Gewichtung
      personalization=personalization, #Personalisierung (Backlinks)
      nstart=personalization,#Personalisierung (Backlinks)
      dangling=personalization #Personalisierung (Backlinks)
      )
  pr = pd.DataFrame.from_dict(pr, orient='index').rename(columns={0:'pr'})
  return pr

def replace_destinations(df, replacer):
  # obey redirects
  df = pd.merge(df,replacer,left_on='Destination',right_on='Address',how='left')
  # Replace Destination with Final Address, If not present use Destination
  df['Destination'] = df['Final Address'].fillna(df['Destination'])
  # If Source is redirected or has Canonical: Drop Link
  df = df[df['Source'].isin(replacer['Address'])==False]
  # drop temp-columns
  df = df.drop(columns=['Address','Final Address'])
  return df


def normalize_links(
    df, redirects=pd.DataFrame(), canonicals=pd.DataFrame(), duplicates=True):
  """Reduce number of Links and delete data you don't need
  """

  df = df.rename(columns={'Anchor':'linkText'})

  print(len(df), 'Links')
  df = df[df['Type']=='Hyperlink'] #only <a href>
  print(len(df), '<a href>-Links, dropped other')
  df['Destination'] = df['Destination'].str.replace('#.*', '') # Sprungmarken-links normalisieren

  # Redirects und Canonicals normalisieren
  # Jaja, erst auflösen, dann ersetzen wäre sauberer
  df = replace_destinations(df, redirects) # obey redirects
  df = replace_destinations(df, canonicals) # obey canonicals

  df = df[df['Source']!=df['Destination']] # links zum gleichen Dokument löschen
  print(len(df), 'to different URLs, dropped Links to self (including #)')
  df = df[df['Link Position']==df['Link Position']] # Drop Links without Position given
  print(len(df), 'links with known Link Position')
  df['weights'] = df['Link Position'].swifter.apply(lambda x: element_weights[x])
  df = df.sort_values('weights', ascending=False).drop_duplicates(subset=['Source','Destination'])
  print(len(df), 'Unique links (dropped duplicates according to link weights)')

  df['linkText'] = df['linkText'].fillna(df['Alt Text']) # Use Alt Text if no linktext given
  df['linkText'] = df['linkText'].fillna('').astype(str) # Ensure Strings
  df['internal'] = df['Destination'].swifter.apply(check_internal) # Check if internal link

  df['Source'] = df['Source'].str.replace('/index.json', '/') # Komische URLs im Crawl (web.dev)
  df['Destination'] = df['Destination'].str.replace('/index.json', '/')# Komische URLs im Crawl (web.dev)
  
  # Only one link from Source to destination
  if duplicates==True:
    df = df.drop_duplicates(subset=['Source','Destination'])

  return df

# %% [markdown]
# # Basic Analysis
# Basis-Analysen allein auf Basis der Exporte ohne weitere Berechnungen:
#
# * Meist genutzte Linktexte
# * Linktexte mit unterschiedlichen Zielseiten
# * Dokumente mit den meisten verschiedenen Linktexten
# * Dokumente mit den meisten ausgehenden externen Links
# * Meistverlinkte externe Dokumente + Linktext
# * Dokumente mit eingehenden Nofollow-Links

# %% [markdown]
# ## Rohdaten laden

# %%
links, docs = read_files()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 69962 Links
# 50079 <a href>-Links, dropped other
# 643007 to different URLs, dropped Links to self (including #)
# 639313 links with known Link Position
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=639313.0, style=ProgressStyle(descript…
# 28905 Unique links (dropped duplicates according to link weights)
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=28905.0, style=ProgressStyle(descripti…

# %% [markdown]
# ## Meistgenutzte Linktexte
# Sind die Linktexte
# * spezifisch?
# * beschreibend?
# * hilfreich?

# %%
# Most used linktexts
links[
    links['internal']==True
].groupby(
    'linkText'
).agg(
    numLinks=('Destination','count'), 
    uniqueDestinations=('Destination',pd.Series.nunique)
).sort_values(
    'numLinks', ascending=False
).head(15)
# Out:
#                                   numLinks  uniqueDestinations
# linkText
# About                                  631                   1
# web.dev                                631                   2
# Community Guidelines                   631                   1
# Podcasts                               630                   1
# Live                                   628                   1
# Learn                                  627                   1
# Measure                                623                   1
# Subscribe                              566                   1
# Blog                                   513                   1
#                                        385                 238
# Return to all articles                 337                  17
# Performance                            152                   1
# RSS Feed                                80                  78
# Case Study                              46                   1
# Lighthouse accessibility scoring        42                   1

# %% [markdown]
# ## Linktexte mit unterschiedlichen Zielen
# Wird der gleiche Linktext für unterschiedliche Zielseiten verwendet.
# * Viele unterschiedliche Texte: schwächen im Template / Kandidaten für Löschung
# * Weniger unterschiedliche Texte: Oft Konkurrenz um den gleichen Begriff

# %%
# Linktexts with most different Destinations
links[
    links['internal']==True
].groupby(
    'linkText'
).agg(
    numLinks=('Destination','count'), 
    uniqueDestinations=('Destination',pd.Series.nunique)
).sort_values(
    'uniqueDestinations', ascending=False
).head(15)
# Out:
#                                               numLinks  uniqueDestinations
# linkText
#                                                    385                 238
# RSS Feed                                            80                  78
# Return to article                                   23                  17
# Return to all articles                             337                  17
# performance budgets                                  8                   4
# here                                                 4                   4
# field metrics                                        5                   4
# screenshot                                           4                   4
# 1                                                    3                   3
# 2                                                    7                   3
# Progressive Web App                                  4                   3
# Lighthouse                                          13                   3
# Lighthouse CI.                                       3                   3
# Discover what it takes to be installable             2                   2
# https://web.dev/sign-in-form-best-practices/         2                   2

# %% [markdown]
# ## Zielseiten mit hoher Linktext-Varianz / Linkziele mit unterschiedlichen Texten
# Seiten die mit besonders vielen unterschiedlichen Linktexten verlinkt werden.
# Unterschiedliche Ankertexte sind grundsätzlich hilfreich, sie sollten aber schon eine Einordnung ermöglichen

# %%
# Destinations with most different Linktexts
links[
    links['internal']==True
].groupby(
    'Destination'
).agg(
    numLinks=('Source','count'), 
    uniqueTexts=('linkText',pd.Series.nunique),
    texts = ('linkText', lambda x: ', '.join(set(x)))
).sort_values(
    'uniqueTexts', ascending=False
).head(15)
# Out:
#                                                     numLinks  ...                                              texts
# Destination                                                   ...
# https://web.dev/authors/jakearchibald/                   328  ...  Chris Anstey, Jonathon Imperiosi, Performance,...
# https://web.dev/fast/                                     80  ...  resource prioritization, Fast load times, use ...
# https://web.dev/user-centric-performance-metrics/         33  ...  , load fast, lab data, in the lab, field metri...
# https://web.dev/reduce-javascript-payloads-with...        28  ...  , code splitting, split, lazy load, Only send ...
# https://web.dev/progressive-web-apps/                     41  ...  Introduction, progressive web app, our guidanc...
# https://web.dev/customize-install/                        15  ...  Add to Home Screen, installable guide, install...
# https://web.dev/http-cache/                               17  ...  The HTTP cache: your first line of defense gui...
# https://web.dev/add-manifest/                             21  ...  , icons array, manifest file, define a Progres...
# https://web.dev/lighthouse-performance/                   44  ...  Collection 33 resources Updated Performance au...
# https://web.dev/remove-unused-code/                       14  ...  , removing unused code, npm makes adding code ...
# https://web.dev/vitals/                                   24  ...  , https://web.dev/vitals/, recommended Core We...
# https://web.dev/native-lazy-loading/                      13  ...  , native lazy loading, native lazy-loading, lo...
# https://web.dev/install-criteria/                         13  ...  Installable, What does it take to be installab...
# https://web.dev/preload-critical-assets/                  15  ...  , preloading critical assets, <link rel="prelo...
# https://web.dev/rail/                                     16  ...  , Measure performance with the RAIL model, Mea...
#
# [15 rows x 3 columns]

# %% [markdown]
# ## Nicht indexierbare Linkziele
# Nicht indexierbare Seiten sollten selten verlinkt werden.
# Bei häufig verlinkten Seiten:
# * Macht es Sinn die Seite zu indexieren?
# * Macht es Sinn die Seite weniger häufig zu verlinken?

# %%
links[
    links['Destination'].isin(
        docs[docs['Indexability']=='Non-Indexable']['Address']
    )
].groupby(
    'Destination'
).agg(
    numLinks=('Source','count'), 
    uniqueSource=('Source',pd.Series.nunique),
    texts = ('linkText', lambda x: ', '.join(set(x)))
).sort_values(
    'numLinks', ascending=False
).head(15)
# Out:
#                                                     numLinks  ...                                              texts
# Destination                                                   ...
# https://web.dev/handbook/content-checklist/                3  ...       web.dev content checklist, content checklist
# https://web.dev/handbook/grammar/                          3  ...  Lists section of the Grammar, mechanics, and u...
# https://web.dev/undefined/                                 3  ...                             Return to all articles
# https://web.dev/handbook/author-profile/                   2  ...                    Author profile, Authors profile
# https://web.dev/handbook/self-assessment-compon...         2  ...                                   Self-assessments
# https://web.dev/handbook/yaml-front-matter/                2  ...                                  YAML front matter
# https://web.dev/cls/(/metrics/                             1  ...                                      field metrics
# https://web.dev/live/\"https://web.dev/prefers-...         1  ...              https://web.dev/prefers-color-scheme/
# https://web.dev/live/\"https://web.dev/storage-...         1  ...                      Service Workers and IndexedDB
# https://web.dev/live/\"https://web.dev/sign-in-...         1  ...       https://web.dev/sign-in-form-best-practices/
# https://web.dev/live/\"https://web.dev/service-...         1  ...                                               this
# https://web.dev/live/\"https://web.dev/defining...         1  ...  https://web.dev/defining-core-web-vitals-thres...
# https://web.dev/live/\"https://web.dev/persiste...         1  ...                                 persistent storage
# https://web.dev/live/\"https://web.dev/hands-on...         1  ...                  https://web.dev/hands-on-portals/
# https://web.dev/live/\"https://web.dev/vitals/\"           1  ...                            https://web.dev/vitals/
#
# [15 rows x 3 columns]

# %% [markdown]
# ## Seiten mit vielen ausgehenden externen Links
# Seiten mit vielen ausgehenden Links sollten inhaltlich geprüft werden.

# %%
# Dokumente mit den meisten ausgehenden externen Links
links[
    links['internal'] == False
].groupby(
    'Source'
).agg(
    numLinks=('Destination','count'), 
    uniqueDestinations=('Destination',pd.Series.nunique),
).sort_values(
    'numLinks',ascending=False
).head(10)
# Out:
#                                                    numLinks  uniqueDestinations
# Source
# https://web.dev/prefers-color-scheme/                    96                  96
# https://web.dev/live/                                    92                  92
# https://web.dev/covid19/                                 76                  76
# https://web.dev/quictransport/                           72                  72
# https://web.dev/overloaded-server/                       69                  69
# https://web.dev/optimize-lcp/                            62                  62
# https://web.dev/next-gen-css-2019/                       62                  62
# https://web.dev/shape-detection/                         62                  62
# https://web.dev/digging-into-the-privacy-sandbox/        61                  61
# https://web.dev/websocketstream/                         61                  61

# %% [markdown]
# ## Externe Dokumente mit vielen eingehenden Links
# Diese Dokumente werden häufig verlinkt. Ist das sinnvoll?

# %%
# Meistverlinkte externe Dokumente + Linktext
links[
    (links['internal'] == False) &
    (links['Type'] == 'Hyperlink')
].groupby(
    'Destination'
).agg(
    numLinks=('Source','count'), 
    texts = ('linkText', lambda x: ', '.join(set(x)))
).sort_values(
    'numLinks',ascending=False
).head(15)
# Out:
#                                                     numLinks                                     texts
# Destination
# https://www.apache.org/licenses/LICENSE-2.0              632                        Apache 2.0 License
# https://policies.google.com/technologies/cookies         632                              More details
# https://developers.google.com/                           632                         Google Developers
# https://developers.google.com/products                   632                              All products
# https://github.com/GoogleChrome/web.dev/issues/...       632                                File a bug
# https://developers.google.com/terms/site-policies        632           Google Developers Site Policies
# https://creativecommons.org/licenses/by/4.0/             632  Creative Commons Attribution 4.0 License
# https://developers.google.com/web/                       632                          Web Fundamentals
# https://www.twitter.com/@ChromiumDev                     632                                   Twitter
# https://firebase.google.com/                             632                                  Firebase
# https://policies.google.com/                             632                           Terms & Privacy
# https://cloud.google.com/                                632                     Google Cloud Platform
# https://github.com/googlechrome/web.dev                  632                               View source
# https://medium.com/dev-channel                           632                                    Medium
# https://developers.google.com/web/showcase/              632                              Case studies

# %% [markdown]
# ## Interne Links mit Nofollow
# Nofollow bei internen Links nur sehr selten sinnvoll

# %%
# Nofollow-Linked Documents
links[
    links['Follow']==False
].groupby(
    ['Source','internal']
).agg(
    numLinks=('Destination','count'), 
    uniqueDestinations=('Destination',pd.Series.nunique)
).sort_values(
    'numLinks',ascending=False
).head(10)
# Out:
# Empty DataFrame
# Columns: [numLinks, uniqueDestinations]
# Index: []

# %% [markdown]
# # PageRank Calculations
# Wir versuchen uns einer realistischen PageRank-Kalkulation anzunähern.

# %% [markdown]
# ## Basic PageRank

# %%
links, docs = read_files() # Read files to variables

result = pd.merge(
    docs, simulate_pagerank(
        links
    ).rename(columns={'pr': "pr"}),
    left_on='Address',right_index=True, how='outer')

result = result[['Address', 'pr']].sort_values('pr',ascending=False).reset_index().drop(columns='index') # Datenmenge reduzieren
result.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 69962 Links
# 50079 <a href>-Links, dropped other
# 643007 to different URLs, dropped Links to self (including #)
# 639313 links with known Link Position
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=639313.0, style=ProgressStyle(descript…
# 28905 Unique links (dropped duplicates according to link weights)
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=28905.0, style=ProgressStyle(descripti…
#                                       Address        pr
# 0                       https://web.dev/live/  0.013145
# 1                       https://web.dev/blog/  0.009262
# 2                   https://web.dev/podcasts/  0.009104
# 3                            https://web.dev/  0.009025
# 4                    https://web.dev/measure/  0.009000
# 5       https://web.dev/community-guidelines/  0.008988
# 6                      https://web.dev/learn/  0.008949
# 7                      https://web.dev/about/  0.008949
# 8     https://github.com/googlechrome/web.dev  0.008725
# 9  https://developers.google.com/web/updates/  0.008725

# %% [markdown]
# ## Wir löschen Nofollow und Links auf/von Noindex-Seiten

# %%
links, docs = read_files() # Read files to variables

# Wir löschen Nofollow-Links:
links = links[links['Follow']==True]

indexable = docs[docs['Indexability']=='Indexable']['Address'] # all indexable URLs
links = links[ #Only internal, only indexable
          (links['Source'].isin(indexable)) &
          (links['Destination'].isin(indexable))
        ]

pr_name = 'pr_noindex'
result_old = result # wir sichern die Berechnung aus dem vorherigen Schritt
result = pd.merge(
    docs, simulate_pagerank(
        links
    ).rename(columns={'pr': pr_name}), # Wir benennen den PR anders
    left_on='Address',right_index=True, how='outer')

result = result[['Address', pr_name]].sort_values(pr_name, ascending=False).reset_index().drop(columns='index')

pd.merge( # wir vergleichen alt und neu
    result, result_old, on='Address',how='outer'
).sort_values(pr_name, ascending=False).head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 69962 Links
# 50079 <a href>-Links, dropped other
# 643007 to different URLs, dropped Links to self (including #)
# 639313 links with known Link Position
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=639313.0, style=ProgressStyle(descript…
# 28905 Unique links (dropped duplicates according to link weights)
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=28905.0, style=ProgressStyle(descripti…
#                                   Address  pr_noindex        pr
# 0               https://web.dev/podcasts/    0.032554  0.009104
# 1   https://web.dev/community-guidelines/    0.032554  0.008988
# 2                  https://web.dev/about/    0.032554  0.008949
# 3                  https://web.dev/learn/    0.032554  0.008949
# 4                   https://web.dev/blog/    0.032554  0.009262
# 5                        https://web.dev/    0.032554  0.009025
# 6                   https://web.dev/live/    0.032554  0.013145
# 7                https://web.dev/measure/    0.032554  0.009000
# 8             https://web.dev/newsletter/    0.029781  0.008348
# 9  https://web.dev/authors/jakearchibald/    0.017412  0.005127

# %% [markdown]
# ## Wir versuchen einen Reasonable Surfer zu simulieren
# (indem wir als einfach Annährung Links aus Navigation und Footer ignorieren)

# %%
links, docs = read_files() # Read files to variables

# Wir löschen Nofollow-Links:
links = links[links['Follow']==True]

indexable = docs[docs['Indexability']=='Indexable']['Address']
links = links[
          (links['Source'].isin(indexable)) &
          (links['Destination'].isin(indexable))
        ]

pr_name = 'pr_reasonable'
result_old = result # wir sichern die Berechnung aus dem vorherigen Schritt
result = pd.merge(
    docs, simulate_pagerank(
        links, weight='weights'
    ).rename(columns={'pr': pr_name}),
    left_on='Address',right_index=True, how='outer')

result = result[['Address', pr_name]].sort_values(pr_name, ascending=False).reset_index().drop(columns='index')

pd.merge( # wir vergleichen alt und neu
    result, result_old, on='Address',how='outer'
).sort_values(pr_name, ascending=False).head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 69962 Links
# 50079 <a href>-Links, dropped other
# 643007 to different URLs, dropped Links to self (including #)
# 639313 links with known Link Position
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=639313.0, style=ProgressStyle(descript…
# 28905 Unique links (dropped duplicates according to link weights)
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=28905.0, style=ProgressStyle(descripti…
#                                   Address  pr_reasonable  pr_backlinks
# 0             https://web.dev/newsletter/       0.077724      0.073989
# 1  https://web.dev/authors/jakearchibald/       0.035989      0.034335
# 2                https://web.dev/measure/       0.009557      0.001563
# 3                  https://web.dev/learn/       0.009167      0.002915
# 4                   https://web.dev/blog/       0.009155      0.005656
# 5                   https://web.dev/live/       0.009014      0.003746
# 6               https://web.dev/podcasts/       0.008926      0.000380
# 7                  https://web.dev/about/       0.008828      0.000523
# 8                        https://web.dev/       0.008828      0.002304
# 9   https://web.dev/community-guidelines/       0.008828           NaN

# %% [markdown]
# ## Wir beziehen Backlinks mit ein
#
# Im Beispiel Backlinks von ahrefs logarithmiert als Personalisierung für die PageRank-Funktion übergeben. Andere Werde zur Bestimmung des externen Trusts ebenfalls denkbar: Klicks, Impressions, Social Signals.
#
# Aber: Cross-Check: Sinnhaftigkeit, Ursache-/Wirkungsbeziehung

# %%
backlinks = files.upload() # Backlink-Export aus AHREFs hochladen
# Out:
#      <input type="file" id="files-f035ce65-50e1-4546-912f-4ba0d48c2539" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f035ce65-50e1-4546-912f-4ba0d48c2539">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving backlinks.csv to backlinks (1).csv

# %%
backlinks = pd.read_csv(io.BytesIO(backlinks['backlinks.csv'])) # Datei einlesen
indexable = docs[docs['Indexability']=='Indexable']['Address']

df = pd.merge(
    indexable,backlinks[['Page URL', 'URL Rating (desc)']],
    left_on='Address', right_on='Page URL',
    how='left'
).set_index('Address')['URL Rating (desc)'].fillna(0)+0.001 # Backlinkziele mit indexierbaren URLs zusammenfassen
backlinks = np.log(df)/np.log(df.max()) # Logarithmisch anpassen, um starke / Schwache URLs zu relativieren
backlinks = backlinks.to_dict() # Dictionary für einfaches Handling

# %%
links, docs = read_files() # Read files to variables

# Wir löschen Nofollow-Links:
links = links[links['Follow']==True]

indexable = docs[docs['Indexability']=='Indexable']['Address']
links = links[
          (links['Source'].isin(indexable)) &
          (links['Destination'].isin(indexable))
        ]

pr_name = 'pr_backlinks'
result_old = result # wir sichern die Berechnung aus dem vorherigen Schritt
result = pd.merge(
    docs, simulate_pagerank(
        links,
        weight='weights',
        personalization = backlinks # Einbindung der Backlinks als Personalisierungswert
    ).rename(columns={'pr': pr_name}),
    left_on='Address',right_index=True, how='outer')

result = result[['Address', pr_name]].sort_values(pr_name, ascending=False).reset_index().drop(columns='index')

pd.merge( # wir vergleichen alt und neu
    result, result_old, on='Address',how='outer'
).sort_values(pr_name, ascending=False).head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 69962 Links
# 50079 <a href>-Links, dropped other
# 643007 to different URLs, dropped Links to self (including #)
# 639313 links with known Link Position
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=639313.0, style=ProgressStyle(descript…
# 28905 Unique links (dropped duplicates according to link weights)
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=28905.0, style=ProgressStyle(descripti…
#                                   Address  pr_backlinks  pr_reasonable
# 0             https://web.dev/newsletter/      0.077653       0.077724
# 1  https://web.dev/authors/jakearchibald/      0.036309       0.035989
# 2                https://web.dev/measure/      0.009656       0.009557
# 3                  https://web.dev/learn/      0.009134       0.009167
# 4                   https://web.dev/live/      0.009118       0.009014
# 5               https://web.dev/podcasts/      0.008979       0.008926
# 6                        https://web.dev/      0.008971       0.008828
# 7                   https://web.dev/blog/      0.008959       0.009155
# 8                  https://web.dev/about/      0.008885       0.008828
# 9   https://web.dev/community-guidelines/      0.008856       0.008828

# %% [markdown]
# # Wir versuchen mal ein paar Aggregationen

# %%
pd.merge(
    pr.reset_index().rename(columns={'index':'Address'}), 
    docs[['Address','Content']],
    on='Address', how='left'
).groupby('Content').agg(
    anzahl=('Address','count'), 
    pr=('pr',sum)
).sort_values('pr')
# Out:
#                           anzahl        pr
# Content
# image/svg+xml                  6  0.001882
# image/jpeg                     6  0.002128
# image/png                     11  0.003740
# application/xml               78  0.016780
# text/html; charset=UTF-8     103  0.150478
# text/html                    524  0.824992

# %% [markdown]
# ## Externe Ziele

# %%
df = pr.reset_index().rename(columns={'index':'Address'})
df['internal'] = df['pr'].astype(str).swifter.apply(lambda x: check_internal(x))
df.groupby('internal').agg(
    anzahl=('Address','count'), 
    pr=('pr',sum)
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=728.0, style=ProgressStyle(description…
#           anzahl   pr
# internal
# False        728  1.0

# %% [markdown]
# ## Group by URL-Segment

# %%
def url_grouping(url): # so baut man das natürlich nicht
  if check_internal(url) == False:
    return 'external'
  if url.endswith('.xml'):
    return 'RSS'
  if url.endswith('.png'):
    return 'Image'
  if url.endswith('.svg'):
    return 'Image'
  if url.endswith('.jpg'):
    return 'Image'
  if 'handbook' in url:
    return '/handbook/'
  if 'codelab' in url:
    return 'codelab'
  if '/newsletter/archive' in url:
    return 'Newsletter Archive'
  if url in ['https://web.dev/', 'https://web.dev/live/', 'https://web.dev/blog/', 'https://web.dev/learn/','https://web.dev/measure/', 'https://web.dev/about/']:
    return 'Main Nav'
  if 'authors' in url:
    return 'authors'
  if 'tag' in url:
    return 'tag'
  if '/blog/' in url:
    return 'Blog-Pagination'
  return np.nan

df = pr.reset_index().rename(columns={'index':'url'})
df['url_group'] = df['url'].swifter.apply(lambda x: url_grouping(x))

df[
   (df['url_group']!=df['url_group'])
   ].sort_values('pr')
df['url_group'] = df['url_group'].fillna('article')
df.groupby('url_group').agg(
    anzahl=('url','count'),
    pr=('pr',sum)
).sort_values('pr',ascending=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=728.0, style=ProgressStyle(description…

# %% [markdown]
# ## Group by Custom Extraction von Breadcrumb-Elementen oder Tags

# %%
# Upload files (bei größeren Datenmengen als .gz hochladen)
extractions = files.upload()
# Out:
#      <input type="file" id="files-c62c2539-e029-4204-b926-d33aee6a8dcb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c62c2539-e029-4204-b926-d33aee6a8dcb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving custom_extraction_all.csv to custom_extraction_all.csv

# %%
extractions = pd.read_csv(io.BytesIO(extractions['custom_extraction_all.csv']))
extractions
# Out:
#                                          Address  ...          Tag 1
# 0                               https://web.dev/  ...            NaN
# 1       https://web.dev/aria-poison-or-antidote/  ...  accessibility
# 2                       https://web.dev/measure/  ...            NaN
# 3            https://web.dev/tags/accessibility/  ...            NaN
# 4             https://web.dev/tags/capabilities/  ...            NaN
# ..                                           ...  ...            ...
# 671              https://web.dev/handbook/voice/  ...            NaN
# 672            https://web.dev/handbook/reviews/  ...            NaN
# 673     https://web.dev/handbook/author-profile/  ...            NaN
# 674  https://web.dev/handbook/yaml-front-matter/  ...            NaN
# 675          https://web.dev/handbook/word-list/  ...            NaN
#
# [676 rows x 6 columns]

# %%
pd.merge(
    pr.reset_index().rename(columns={'index':'Address'}), 
    extractions[['Address','Tag 1']],
    on='Address', how='left'
).groupby('Tag 1').agg(
    anzahl=('Address','count'), 
    pr=('pr',sum)
).sort_values('pr', ascending=False)
# Out:
#                       anzahl        pr
# Tag 1
# performance              112  0.169003
# newsletter                 4  0.078981
# capabilities              21  0.030447
# progressive-web-apps      16  0.026222
# security                  16  0.014443
# case-study                 8  0.010198
# css                        8  0.008539
# accessibility              6  0.008205
# payments                   8  0.007811
# angular                    9  0.007090
# web-vitals                 2  0.005673
# augmented-reality          4  0.004953
# e-commerce                 3  0.004163
# metrics                    2  0.004016
# forms                      3  0.003747
# media                      5  0.003700
# network                    3  0.003453
# images                     2  0.003006
# privacy                    3  0.002926
# reliable                   1  0.002506
# dark-mode                  1  0.002458
# dom                        2  0.002111
# javascript                 3  0.002096
# storage                    2  0.002032
# chrome-ux-report           1  0.001889
# seo                        2  0.001883
# top tips                   1  0.001708
# media-queries              1  0.001099
# SXG                        2  0.001086
# speed                      1  0.000986
# identity                   1  0.000978
# tools                      1  0.000972
# twa                        1  0.000950
# perforamnce                1  0.000912
# fonts                      1  0.000903
# games                      1  0.000900
# PROXX                      1  0.000898
# html                       1  0.000895
# houdini                    1  0.000887
# service-worker             1  0.000886
# memory                     1  0.000879
# web-bundles                1  0.000827
# engineering-blog           1  0.000817
# web-workers                1  0.000808
# text-fragments             1  0.000777
# origin-trials              1  0.000773
# appcache                   1  0.000769
# animations                 1  0.000761
# webassembly                1  0.000755
# idle-detection             1  0.000745
# android                    1  0.000654
# portals                    1  0.000641
# webdev                     1  0.000639
# backpressure               1  0.000639
# payment                    1  0.000561
# visual-search              1  0.000534
# web-components             1  0.000534
# deprecation                1  0.000531
# notifications              1  0.000431
